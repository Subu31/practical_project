# %%
class DataLoadError(Exception):
    """Exception raised for errors in the data loading process."""
    pass

# %%
import unittest
import numpy as np
import pandas as pd
from sqlalchemy import create_engine, MetaData, Table, Column, Float
from sqlalchemy.orm import sessionmaker
from bokeh.plotting import figure, output_file, save, show
from bokeh.layouts import column

def load_data_from_csv(file_path):
    """
    Load data from a CSV file into a pandas DataFrame.

    Args:
        file_path (str): Path to the CSV file.

    Returns:
        pandas.DataFrame: DataFrame containing the loaded data.
    """
    print(f"Loading data from {file_path}")
    df = pd.read_csv(file_path)
    print(f"Loaded {len(df)} rows with columns: {list(df.columns)}")
    return df


def create_table_from_df(engine, table_name, df):
    """
    Create a database table based on the structure of a DataFrame.

    Args:
        engine: SQLAlchemy engine object.
        table_name (str): Name of the table to be created.
        df (pandas.DataFrame): DataFrame whose structure defines the table schema.
    """
    metadata = MetaData()

    # Create table definition based on DataFrame columns
    columns = [Column('x', Float)]
    for col in df.columns[1:]:
        columns.append(Column(col, Float))

    table = Table(table_name, metadata, *columns)
    metadata.create_all(engine)
    print(f"Table '{table_name}' created with columns: {df.columns}")


def insert_data(session, engine, table_name, df):
    """
    Insert data from a DataFrame into a database table.

    Args:
        session: SQLAlchemy session object.
        engine: SQLAlchemy engine object.
        table_name (str): Name of the table to insert data into.
        df (pandas.DataFrame): DataFrame containing the data to be inserted.
    """
    metadata = MetaData()
    metadata.reflect(bind=engine)
    table = metadata.tables[table_name]

    for index, row in df.iterrows():
        ins = table.insert().values(row.to_dict())
        session.execute(ins)
    session.commit()
    print(f"Inserted {len(df)} rows into table '{table_name}'")


def load_table_to_df(engine, table_name):
    """
    Load data from a database table into a pandas DataFrame.

    Args:
        engine: SQLAlchemy engine object.
        table_name (str): Name of the table to load data from.

    Returns:
        pandas.DataFrame: DataFrame containing the loaded data.
    """
    query = f"SELECT * FROM {table_name}"
    df = pd.read_sql(query, engine)
    return df


def find_best_ideal_functions(training_df, ideal_df):
    """
    Find the best ideal functions for each training function.

    Args:
        training_df (pandas.DataFrame): DataFrame containing training data.
        ideal_df (pandas.DataFrame): DataFrame containing ideal functions.

    Returns:
        dict: A dictionary mapping each training function to its best corresponding ideal function.
    """
    best_ideal_funcs = {}
    for train_col in training_df.columns[1:]:  # Skip 'x' column
        min_ssr = float('inf')
        best_func = None
        for ideal_col in ideal_df.columns[1:]:  # Skip 'x' column
            ssr = np.sum((training_df[train_col] - ideal_df[ideal_col]) ** 2)
            if ssr < min_ssr:
                min_ssr = ssr
                best_func = ideal_col
        best_ideal_funcs[train_col] = best_func
    return best_ideal_funcs


def approximate_test_data(test_df, ideal_df, best_ideal_funcs):
    """
    Approximate test data using the best ideal functions identified.

    Args:
        test_df (pandas.DataFrame): DataFrame containing test data.
        ideal_df (pandas.DataFrame): DataFrame containing ideal functions.
        best_ideal_funcs (dict): Dictionary mapping each training function to its best ideal function.

    Returns:
        dict: A dictionary containing the residuals for each test data point.
    """
    residuals = {}
    for test_idx, test_row in test_df.iterrows():
        x_val = test_row['x']
        y_test = test_row['y']
        closest_ideal = None
        min_residual = float('inf')
        for ideal_col in best_ideal_funcs.values():
            y_ideal = ideal_df.loc[ideal_df['x'] == x_val, ideal_col].values[0]
            residual = np.abs(y_test - y_ideal)
            if residual < min_residual:
                min_residual = residual
                closest_ideal = ideal_col
        residuals[test_idx] = (x_val, y_test, closest_ideal, min_residual)
    return residuals


class TestFunctions(unittest.TestCase):
    def test_load_data_from_csv(self):
        """Test loading data from CSV file."""
        test_df = load_data_from_csv('test.csv')
        self.assertEqual(len(test_df), 10)

    def test_find_best_ideal_functions(self):
        """Test finding best ideal functions."""
        training_df = pd.DataFrame({'x': range(10), 'y1': np.random.rand(10), 'y2': np.random.rand(10)})
        ideal_df = pd.DataFrame({'x': range(10), 'y1': np.random.rand(10), 'y2': np.random.rand(10)})
        best_ideal_funcs = find_best_ideal_functions(training_df, ideal_df)
        self.assertEqual(len(best_ideal_funcs), len(training_df.columns) - 1)


def visualize_training_data(training_df):
    """
    Visualize training data using Bokeh.

    Args:
        training_df (pandas.DataFrame): DataFrame containing training data.
    """
    output_file("training_data.html")
    p = figure(title="Training Data", x_axis_label='x', y_axis_label='y', width=800, height=400)
    for col in training_df.columns[1:]:
        p.line(training_df['x'], training_df[col], legend_label=col)
    p.legend.click_policy="hide"
    save(p)

def visualize_test_data(test_df, residuals, ideal_df):
    """
    Visualize test data and residuals using Bokeh.

    Args:
        test_df (pandas.DataFrame): DataFrame containing test data.
        residuals (dict): Dictionary containing residuals for each test data point.
        ideal_df (pandas.DataFrame): DataFrame containing ideal functions.
    """
    output_file("test_data.html")
    p = figure(title="Test Data", x_axis_label='x', y_axis_label='y', width=800, height=400)
    p.circle(test_df['x'], test_df['y'], legend_label='Test Data', color='blue')
    for idx, res in residuals.items():
        p.line([res[0], res[0]], [res[1], ideal_df.loc[ideal_df['x'] == res[0], res[2]].values[0]],
               legend_label=f'Test Data {idx}', color='red')
    p.legend.click_policy = "hide"
    save(p)
class DataVisualizer:
    @staticmethod
    def plot_data(training_df, ideal_df, test_df, residuals, best_ideal_funcs):
        """
        Plot training data, ideal functions, test data, and residuals using Bokeh.

        Args:
            training_df (pandas.DataFrame): DataFrame containing training data.
            ideal_df (pandas.DataFrame): DataFrame containing ideal functions.
            test_df (pandas.DataFrame): DataFrame containing test data.
            residuals (dict): Dictionary containing residuals for each test data point.
            best_ideal_funcs (dict): Dictionary mapping each training function to its best ideal function.
        """
        p = figure(title="Training Data vs Ideal Functions")
        for col in training_df.columns[1:]:
            p.line(training_df['x'], training_df[col], legend_label=f"Training {col}", line_width=2)
        for col in best_ideal_funcs.values():
            p.line(ideal_df['x'], ideal_df[col], legend_label=f"Ideal {col}", line_width=2, line_dash="dashed")

        p2 = figure(title="Test Data and Residuals", x_range=p.x_range, y_range=p.y_range)
        p2.scatter(test_df['x'], test_df['y'], legend_label="Test Data", color="red")
        for idx, (x, y_test, closest_ideal, residual) in residuals.items():
            p2.line([x, x], [y_test, ideal_df.loc[ideal_df['x'] == x, closest_ideal].values[0]], line_width=1, color="black")

        show(column(p, p2))
def main():
    """
    Main function to orchestrate the data loading, analysis, and visualization process.
    """
    # Database setup
    engine = create_engine(r'sqlite:///C:/Users/ECS/Desktop/assignment/database.db')
    Session = sessionmaker(bind=engine)
    session = Session()

    # Load data from tables
    training_df = load_table_to_df(engine, 'training_data')
    ideal_df = load_table_to_df(engine, 'ideal_functions')
    test_df = load_table_to_df(engine, 'test_data')

    # Find the best ideal functions for training data
    best_ideal_funcs = find_best_ideal_functions(training_df, ideal_df)
    print("Best ideal functions identified for each training function:")
    print(best_ideal_funcs)

    # Approximate the test data using the best ideal functions
    residuals = approximate_test_data(test_df, ideal_df, best_ideal_funcs)
    print("Residuals for test data approximation:")
    for idx, res in residuals.items():
        print(f"Test Data Index {idx}: x = {res[0]}, y_test = {res[1]}, closest_ideal = {res[2]}, residual = {res[3]}")

    # Visualize training data
    visualize_training_data(training_df)

    # Visualize test data
    DataVisualizer.plot_data(training_df, ideal_df, test_df, residuals, best_ideal_funcs)


if __name__ == '__main__':
    main()
# Out:
# Best ideal functions identified for each training function:
# {'y1': 'y42', 'y2': 'y41', 'y3': 'y11', 'y4': 'y48'}
# Residuals for test data approximation:
# Test Data Index 0: x = 17.5, y_test = 34.16104, closest_ideal = y41, residual = 0.351148000000002
# Test Data Index 1: x = 0.3, y_test = 1.2151024, closest_ideal = y41, residual = 0.4673422999999999
# Test Data Index 2: x = -8.7, y_test = -16.843908, closest_ideal = y41, residual = 0.8875770000000003
# Test Data Index 3: x = -19.2, y_test = -37.17087, closest_ideal = y41, residual = 1.4007900000000006
# Test Data Index 4: x = -11.0, y_test = -20.263054, closest_ideal = y41, residual = 1.2369519999999987
# Test Data Index 5: x = 0.8, y_test = 1.4264555, closest_ideal = y41, residual = 0.5322224999999998
# Test Data Index 6: x = 14.0, y_test = -0.06650608, closest_ideal = y48, residual = 0.13423253
# Test Data Index 7: x = -10.4, y_test = -2.007094, closest_ideal = y48, residual = 1.7748952
# Test Data Index 8: x = -15.0, y_test = -0.20536347, closest_ideal = y48, residual = 0.45237137
# Test Data Index 9: x = 5.8, y_test = 10.711373, closest_ideal = y41, residual = 0.656326
# Test Data Index 10: x = -7.6, y_test = -39.4954, closest_ideal = y41, residual = 23.811439999999997
# Test Data Index 11: x = -19.8, y_test = -19.915014, closest_ideal = y11, residual = 0.11501399999999862
# Test Data Index 12: x = 18.9, y_test = 19.193245, closest_ideal = y11, residual = 0.2932450000000024
# Test Data Index 13: x = 6.9, y_test = 7.8014545, closest_ideal = y11, residual = 0.9014544999999998
# Test Data Index 14: x = 8.8, y_test = -0.7260513, closest_ideal = y48, residual = 0.48884017999999996
# Test Data Index 15: x = -9.5, y_test = -9.652251, closest_ideal = y11, residual = 0.1522509999999997
# Test Data Index 16: x = 8.1, y_test = -16.659458, closest_ideal = y42, residual = 0.3376860000000015
# Test Data Index 17: x = 7.7, y_test = -14.40003, closest_ideal = y42, residual = 0.9232830000000014
# Test Data Index 18: x = 4.5, y_test = -0.8401146, closest_ideal = y48, residual = 0.9431442200000001
# Test Data Index 19: x = 10.7, y_test = 38.790028, closest_ideal = y41, residual = 17.868346
# Test Data Index 20: x = -8.8, y_test = 16.571745, closest_ideal = y42, residual = 0.6227090000000004
# Test Data Index 21: x = 11.7, y_test = 31.159376, closest_ideal = y41, residual = 8.140367000000001
# Test Data Index 22: x = -15.4, y_test = 29.490164, closest_ideal = y42, residual = 0.833359999999999
# Test Data Index 23: x = 13.9, y_test = 15.310406, closest_ideal = y11, residual = 1.410406
# Test Data Index 24: x = -17.9, y_test = 1.1692159, closest_ideal = y48, residual = 0.9325691899999999
# Test Data Index 25: x = -3.1, y_test = -2.7701359, closest_ideal = y11, residual = 0.3298641
# Test Data Index 26: x = -10.1, y_test = -40.44977, closest_ideal = y41, residual = 20.562305000000002
# Test Data Index 27: x = -11.8, y_test = 24.606413, closest_ideal = y42, residual = 0.6461959999999998
# Test Data Index 28: x = 18.8, y_test = 37.5234, closest_ideal = y41, residual = 0.05183299999999491
# Test Data Index 29: x = -14.3, y_test = -30.492392, closest_ideal = y41, residual = 1.399006
# Test Data Index 30: x = 6.3, y_test = 13.4726305, closest_ideal = y41, residual = 0.8642234999999996
# Test Data Index 31: x = -18.8, y_test = 13.410461, closest_ideal = y48, residual = 13.385723586
# Test Data Index 32: x = 7.7, y_test = 15.392297, closest_ideal = y41, residual = 0.5017870000000002
# Test Data Index 33: x = -2.8, y_test = -3.2989988, closest_ideal = y11, residual = 0.4989988000000003
# Test Data Index 34: x = -8.2, y_test = -16.575344, closest_ideal = y41, residual = 0.2950209999999984
# Test Data Index 35: x = 2.8, y_test = -36.151726, closest_ideal = y42, residual = 30.080614999999995
# Test Data Index 36: x = 14.1, y_test = 0.31000805, closest_ideal = y48, residual = 0.29144169
# Test Data Index 37: x = -4.0, y_test = -8.339117, closest_ideal = y41, residual = 0.7175183
# Test Data Index 38: x = 5.8, y_test = 11.520408, closest_ideal = y41, residual = 0.15270899999999976
# Test Data Index 39: x = 17.1, y_test = -34.927006, closest_ideal = y42, residual = 0.6381000000000014
# Test Data Index 40: x = 13.5, y_test = -21.734203, closest_ideal = y42, residual = 4.968336999999998
# Test Data Index 41: x = 14.7, y_test = -0.27583703, closest_ideal = y48, residual = 0.05019836999999999
# Test Data Index 42: x = 13.7, y_test = 28.15797, closest_ideal = y41, residual = 0.3049919999999986
# Test Data Index 43: x = -7.9, y_test = -0.21800028, closest_ideal = y48, residual = 0.240976993
# Test Data Index 44: x = -7.3, y_test = -9.224243, closest_ideal = y11, residual = 1.9242429999999997
# Test Data Index 45: x = -9.1, y_test = -8.293134, closest_ideal = y11, residual = 0.8068659999999994
# Test Data Index 46: x = 4.6, y_test = -7.905099, closest_ideal = y42, residual = 1.3509770000000003
# Test Data Index 47: x = 19.7, y_test = 38.955273, closest_ideal = y41, residual = 0.8205140000000029
# Test Data Index 48: x = 17.6, y_test = -35.10534, closest_ideal = y42, residual = 0.06320999999999799
# Test Data Index 49: x = -4.5, y_test = -9.88685, closest_ideal = y41, residual = 1.3756150000000016
# Test Data Index 50: x = -5.7, y_test = 2.4492908, closest_ideal = y48, residual = 2.21945867
# Test Data Index 51: x = 13.6, y_test = 12.65079, closest_ideal = y11, residual = 0.949209999999999
# Test Data Index 52: x = -1.0, y_test = 38.057026, closest_ideal = y42, residual = 35.7868749
# Test Data Index 53: x = 3.0, y_test = -0.24295843, closest_ideal = y48, residual = 0.17310456000000002
# Test Data Index 54: x = -18.3, y_test = -19.014248, closest_ideal = y11, residual = 0.7142479999999978
# Test Data Index 55: x = 7.7, y_test = 7.778326, closest_ideal = y11, residual = 0.07832599999999967
# Test Data Index 56: x = -12.4, y_test = 1.2345738, closest_ideal = y48, residual = 1.15291502
# Test Data Index 57: x = 11.7, y_test = 11.846094, closest_ideal = y11, residual = 0.1460940000000015
# Test Data Index 58: x = -2.8, y_test = -2.6560864, closest_ideal = y11, residual = 0.14391359999999986
# Test Data Index 59: x = -9.7, y_test = 18.183699, closest_ideal = y42, residual = 0.735119000000001
# Test Data Index 60: x = 10.4, y_test = 10.410377, closest_ideal = y11, residual = 0.01037700000000008
# Test Data Index 61: x = -19.1, y_test = -38.155376, closest_ideal = y41, residual = 0.16854100000000471
# Test Data Index 62: x = -14.7, y_test = -23.71317, closest_ideal = y41, residual = 6.109703999999997
# Test Data Index 63: x = 9.2, y_test = 7.5970726, closest_ideal = y11, residual = 1.6029273999999996
# Test Data Index 64: x = -9.6, y_test = -10.995601, closest_ideal = y11, residual = 1.395601000000001
# Test Data Index 65: x = -3.2, y_test = 7.2523284, closest_ideal = y42, residual = 1.3514757
# Test Data Index 66: x = -10.6, y_test = 19.67348, closest_ideal = y42, residual = 1.3338520000000003
# Test Data Index 67: x = -12.5, y_test = 25.675346, closest_ideal = y42, residual = 0.1764460000000021
# Test Data Index 68: x = -5.3, y_test = -4.3722925, closest_ideal = y11, residual = 0.9277074999999995
# Test Data Index 69: x = 14.6, y_test = -0.677509, closest_ideal = y48, residual = 0.47775363000000004
# Test Data Index 70: x = -16.8, y_test = -34.480774, closest_ideal = y41, residual = 1.3245579999999961
# Test Data Index 71: x = 2.842171e-13, y_test = 1.0261426, closest_ideal = y42, residual = 0.5261426
# Test Data Index 72: x = 5.7, y_test = 31.600712, closest_ideal = y41, residual = 20.476054
# Test Data Index 73: x = -4.6, y_test = -0.4953994, closest_ideal = y48, residual = 0.43967691999999997
# Test Data Index 74: x = -15.0, y_test = -13.989205, closest_ideal = y11, residual = 1.0107949999999999
# Test Data Index 75: x = -1.3, y_test = 17.94832, closest_ideal = y42, residual = 15.214570599999998
# Test Data Index 76: x = -4.6, y_test = -3.321962, closest_ideal = y11, residual = 1.2780379999999996
# Test Data Index 77: x = -8.2, y_test = 15.767493, closest_ideal = y42, residual = 0.4629299999999983
# Test Data Index 78: x = 13.3, y_test = 27.148037, closest_ideal = y41, residual = 0.21325299999999814
# Test Data Index 79: x = 18.2, y_test = 18.535152, closest_ideal = y11, residual = 0.3351520000000008
# Test Data Index 80: x = -10.0, y_test = 18.979424, closest_ideal = y42, residual = 0.6010390000000001
# Test Data Index 81: x = -12.0, y_test = 0.670648, closest_ideal = y48, residual = 0.4442534
# Test Data Index 82: x = 18.7, y_test = 0.8322721, closest_ideal = y48, residual = 0.90594
# Test Data Index 83: x = -20.0, y_test = -19.28497, closest_ideal = y11, residual = 0.7150299999999987
# Test Data Index 84: x = 12.5, y_test = 23.7267, closest_ideal = y41, residual = 1.2401389999999992
# Test Data Index 85: x = -19.3, y_test = -38.458572, closest_ideal = y41, residual = 0.3591120000000032
# Test Data Index 86: x = 16.3, y_test = 16.863394, closest_ideal = y11, residual = 0.5633939999999988
# Test Data Index 87: x = 6.7, y_test = 6.232807, closest_ideal = y11, residual = 0.46719299999999997
# Test Data Index 88: x = 9.8, y_test = -21.007133, closest_ideal = y42, residual = 0.9419210000000007
# Test Data Index 89: x = 10.1, y_test = 20.669428, closest_ideal = y41, residual = 0.7819630000000011
# Test Data Index 90: x = 13.6, y_test = 28.536507, closest_ideal = y41, residual = 0.9069259999999986
# Test Data Index 91: x = -14.4, y_test = -15.698657, closest_ideal = y11, residual = 1.2986570000000004
# Test Data Index 92: x = -9.1, y_test = -31.648926, closest_ideal = y41, residual = 13.289376999999998
# Test Data Index 93: x = 16.6, y_test = -33.41535, closest_ideal = y42, residual = 0.09856200000000115
# Test Data Index 94: x = -12.4, y_test = 26.599438, closest_ideal = y42, residual = 1.3063409999999998
# Test Data Index 95: x = -1.9, y_test = -4.0369043, closest_ideal = y41, residual = 0.23624570000000045
# Test Data Index 96: x = 12.2, y_test = -0.010358215, closest_ideal = y48, residual = 0.156869245
# Test Data Index 97: x = 16.5, y_test = -33.964134, closest_ideal = y42, residual = 0.6129340000000028
# Test Data Index 98: x = 5.3, y_test = -10.291622, closest_ideal = y42, residual = 0.031190999999999747
# Test Data Index 99: x = 17.9, y_test = 28.078455, closest_ideal = y41, residual = 7.314964999999997
# Test Data Index 100: x = 17.5, y_test = 34.16104, closest_ideal = y41, residual = 0.351148000000002
# Test Data Index 101: x = 0.3, y_test = 1.2151024, closest_ideal = y41, residual = 0.4673422999999999
# Test Data Index 102: x = -8.7, y_test = -16.843908, closest_ideal = y41, residual = 0.8875770000000003
# Test Data Index 103: x = -19.2, y_test = -37.17087, closest_ideal = y41, residual = 1.4007900000000006
# Test Data Index 104: x = -11.0, y_test = -20.263054, closest_ideal = y41, residual = 1.2369519999999987
# Test Data Index 105: x = 0.8, y_test = 1.4264555, closest_ideal = y41, residual = 0.5322224999999998
# Test Data Index 106: x = 14.0, y_test = -0.06650608, closest_ideal = y48, residual = 0.13423253
# Test Data Index 107: x = -10.4, y_test = -2.007094, closest_ideal = y48, residual = 1.7748952
# Test Data Index 108: x = -15.0, y_test = -0.20536347, closest_ideal = y48, residual = 0.45237137
# Test Data Index 109: x = 5.8, y_test = 10.711373, closest_ideal = y41, residual = 0.656326
# Test Data Index 110: x = -7.6, y_test = -39.4954, closest_ideal = y41, residual = 23.811439999999997
# Test Data Index 111: x = -19.8, y_test = -19.915014, closest_ideal = y11, residual = 0.11501399999999862
# Test Data Index 112: x = 18.9, y_test = 19.193245, closest_ideal = y11, residual = 0.2932450000000024
# Test Data Index 113: x = 6.9, y_test = 7.8014545, closest_ideal = y11, residual = 0.9014544999999998
# Test Data Index 114: x = 8.8, y_test = -0.7260513, closest_ideal = y48, residual = 0.48884017999999996
# Test Data Index 115: x = -9.5, y_test = -9.652251, closest_ideal = y11, residual = 0.1522509999999997
# Test Data Index 116: x = 8.1, y_test = -16.659458, closest_ideal = y42, residual = 0.3376860000000015
# Test Data Index 117: x = 7.7, y_test = -14.40003, closest_ideal = y42, residual = 0.9232830000000014
# Test Data Index 118: x = 4.5, y_test = -0.8401146, closest_ideal = y48, residual = 0.9431442200000001
# Test Data Index 119: x = 10.7, y_test = 38.790028, closest_ideal = y41, residual = 17.868346
# Test Data Index 120: x = -8.8, y_test = 16.571745, closest_ideal = y42, residual = 0.6227090000000004
# Test Data Index 121: x = 11.7, y_test = 31.159376, closest_ideal = y41, residual = 8.140367000000001
# Test Data Index 122: x = -15.4, y_test = 29.490164, closest_ideal = y42, residual = 0.833359999999999
# Test Data Index 123: x = 13.9, y_test = 15.310406, closest_ideal = y11, residual = 1.410406
# Test Data Index 124: x = -17.9, y_test = 1.1692159, closest_ideal = y48, residual = 0.9325691899999999
# Test Data Index 125: x = -3.1, y_test = -2.7701359, closest_ideal = y11, residual = 0.3298641
# Test Data Index 126: x = -10.1, y_test = -40.44977, closest_ideal = y41, residual = 20.562305000000002
# Test Data Index 127: x = -11.8, y_test = 24.606413, closest_ideal = y42, residual = 0.6461959999999998
# Test Data Index 128: x = 18.8, y_test = 37.5234, closest_ideal = y41, residual = 0.05183299999999491
# Test Data Index 129: x = -14.3, y_test = -30.492392, closest_ideal = y41, residual = 1.399006
# Test Data Index 130: x = 6.3, y_test = 13.4726305, closest_ideal = y41, residual = 0.8642234999999996
# Test Data Index 131: x = -18.8, y_test = 13.410461, closest_ideal = y48, residual = 13.385723586
# Test Data Index 132: x = 7.7, y_test = 15.392297, closest_ideal = y41, residual = 0.5017870000000002
# Test Data Index 133: x = -2.8, y_test = -3.2989988, closest_ideal = y11, residual = 0.4989988000000003
# Test Data Index 134: x = -8.2, y_test = -16.575344, closest_ideal = y41, residual = 0.2950209999999984
# Test Data Index 135: x = 2.8, y_test = -36.151726, closest_ideal = y42, residual = 30.080614999999995
# Test Data Index 136: x = 14.1, y_test = 0.31000805, closest_ideal = y48, residual = 0.29144169
# Test Data Index 137: x = -4.0, y_test = -8.339117, closest_ideal = y41, residual = 0.7175183
# Test Data Index 138: x = 5.8, y_test = 11.520408, closest_ideal = y41, residual = 0.15270899999999976
# Test Data Index 139: x = 17.1, y_test = -34.927006, closest_ideal = y42, residual = 0.6381000000000014
# Test Data Index 140: x = 13.5, y_test = -21.734203, closest_ideal = y42, residual = 4.968336999999998
# Test Data Index 141: x = 14.7, y_test = -0.27583703, closest_ideal = y48, residual = 0.05019836999999999
# Test Data Index 142: x = 13.7, y_test = 28.15797, closest_ideal = y41, residual = 0.3049919999999986
# Test Data Index 143: x = -7.9, y_test = -0.21800028, closest_ideal = y48, residual = 0.240976993
# Test Data Index 144: x = -7.3, y_test = -9.224243, closest_ideal = y11, residual = 1.9242429999999997
# Test Data Index 145: x = -9.1, y_test = -8.293134, closest_ideal = y11, residual = 0.8068659999999994
# Test Data Index 146: x = 4.6, y_test = -7.905099, closest_ideal = y42, residual = 1.3509770000000003
# Test Data Index 147: x = 19.7, y_test = 38.955273, closest_ideal = y41, residual = 0.8205140000000029
# Test Data Index 148: x = 17.6, y_test = -35.10534, closest_ideal = y42, residual = 0.06320999999999799
# Test Data Index 149: x = -4.5, y_test = -9.88685, closest_ideal = y41, residual = 1.3756150000000016
# Test Data Index 150: x = -5.7, y_test = 2.4492908, closest_ideal = y48, residual = 2.21945867
# Test Data Index 151: x = 13.6, y_test = 12.65079, closest_ideal = y11, residual = 0.949209999999999
# Test Data Index 152: x = -1.0, y_test = 38.057026, closest_ideal = y42, residual = 35.7868749
# Test Data Index 153: x = 3.0, y_test = -0.24295843, closest_ideal = y48, residual = 0.17310456000000002
# Test Data Index 154: x = -18.3, y_test = -19.014248, closest_ideal = y11, residual = 0.7142479999999978
# Test Data Index 155: x = 7.7, y_test = 7.778326, closest_ideal = y11, residual = 0.07832599999999967
# Test Data Index 156: x = -12.4, y_test = 1.2345738, closest_ideal = y48, residual = 1.15291502
# Test Data Index 157: x = 11.7, y_test = 11.846094, closest_ideal = y11, residual = 0.1460940000000015
# Test Data Index 158: x = -2.8, y_test = -2.6560864, closest_ideal = y11, residual = 0.14391359999999986
# Test Data Index 159: x = -9.7, y_test = 18.183699, closest_ideal = y42, residual = 0.735119000000001
# Test Data Index 160: x = 10.4, y_test = 10.410377, closest_ideal = y11, residual = 0.01037700000000008
# Test Data Index 161: x = -19.1, y_test = -38.155376, closest_ideal = y41, residual = 0.16854100000000471
# Test Data Index 162: x = -14.7, y_test = -23.71317, closest_ideal = y41, residual = 6.109703999999997
# Test Data Index 163: x = 9.2, y_test = 7.5970726, closest_ideal = y11, residual = 1.6029273999999996
# Test Data Index 164: x = -9.6, y_test = -10.995601, closest_ideal = y11, residual = 1.395601000000001
# Test Data Index 165: x = -3.2, y_test = 7.2523284, closest_ideal = y42, residual = 1.3514757
# Test Data Index 166: x = -10.6, y_test = 19.67348, closest_ideal = y42, residual = 1.3338520000000003
# Test Data Index 167: x = -12.5, y_test = 25.675346, closest_ideal = y42, residual = 0.1764460000000021
# Test Data Index 168: x = -5.3, y_test = -4.3722925, closest_ideal = y11, residual = 0.9277074999999995
# Test Data Index 169: x = 14.6, y_test = -0.677509, closest_ideal = y48, residual = 0.47775363000000004
# Test Data Index 170: x = -16.8, y_test = -34.480774, closest_ideal = y41, residual = 1.3245579999999961
# Test Data Index 171: x = 2.842171e-13, y_test = 1.0261426, closest_ideal = y42, residual = 0.5261426
# Test Data Index 172: x = 5.7, y_test = 31.600712, closest_ideal = y41, residual = 20.476054
# Test Data Index 173: x = -4.6, y_test = -0.4953994, closest_ideal = y48, residual = 0.43967691999999997
# Test Data Index 174: x = -15.0, y_test = -13.989205, closest_ideal = y11, residual = 1.0107949999999999
# Test Data Index 175: x = -1.3, y_test = 17.94832, closest_ideal = y42, residual = 15.214570599999998
# Test Data Index 176: x = -4.6, y_test = -3.321962, closest_ideal = y11, residual = 1.2780379999999996
# Test Data Index 177: x = -8.2, y_test = 15.767493, closest_ideal = y42, residual = 0.4629299999999983
# Test Data Index 178: x = 13.3, y_test = 27.148037, closest_ideal = y41, residual = 0.21325299999999814
# Test Data Index 179: x = 18.2, y_test = 18.535152, closest_ideal = y11, residual = 0.3351520000000008
# Test Data Index 180: x = -10.0, y_test = 18.979424, closest_ideal = y42, residual = 0.6010390000000001
# Test Data Index 181: x = -12.0, y_test = 0.670648, closest_ideal = y48, residual = 0.4442534
# Test Data Index 182: x = 18.7, y_test = 0.8322721, closest_ideal = y48, residual = 0.90594
# Test Data Index 183: x = -20.0, y_test = -19.28497, closest_ideal = y11, residual = 0.7150299999999987
# Test Data Index 184: x = 12.5, y_test = 23.7267, closest_ideal = y41, residual = 1.2401389999999992
# Test Data Index 185: x = -19.3, y_test = -38.458572, closest_ideal = y41, residual = 0.3591120000000032
# Test Data Index 186: x = 16.3, y_test = 16.863394, closest_ideal = y11, residual = 0.5633939999999988
# Test Data Index 187: x = 6.7, y_test = 6.232807, closest_ideal = y11, residual = 0.46719299999999997
# Test Data Index 188: x = 9.8, y_test = -21.007133, closest_ideal = y42, residual = 0.9419210000000007
# Test Data Index 189: x = 10.1, y_test = 20.669428, closest_ideal = y41, residual = 0.7819630000000011
# Test Data Index 190: x = 13.6, y_test = 28.536507, closest_ideal = y41, residual = 0.9069259999999986
# Test Data Index 191: x = -14.4, y_test = -15.698657, closest_ideal = y11, residual = 1.2986570000000004
# Test Data Index 192: x = -9.1, y_test = -31.648926, closest_ideal = y41, residual = 13.289376999999998
# Test Data Index 193: x = 16.6, y_test = -33.41535, closest_ideal = y42, residual = 0.09856200000000115
# Test Data Index 194: x = -12.4, y_test = 26.599438, closest_ideal = y42, residual = 1.3063409999999998
# Test Data Index 195: x = -1.9, y_test = -4.0369043, closest_ideal = y41, residual = 0.23624570000000045
# Test Data Index 196: x = 12.2, y_test = -0.010358215, closest_ideal = y48, residual = 0.156869245
# Test Data Index 197: x = 16.5, y_test = -33.964134, closest_ideal = y42, residual = 0.6129340000000028
# Test Data Index 198: x = 5.3, y_test = -10.291622, closest_ideal = y42, residual = 0.031190999999999747
# Test Data Index 199: x = 17.9, y_test = 28.078455, closest_ideal = y41, residual = 7.314964999999997
# Test Data Index 200: x = 17.5, y_test = 34.16104, closest_ideal = y41, residual = 0.351148000000002
# Test Data Index 201: x = 0.3, y_test = 1.2151024, closest_ideal = y41, residual = 0.4673422999999999
# Test Data Index 202: x = -8.7, y_test = -16.843908, closest_ideal = y41, residual = 0.8875770000000003
# Test Data Index 203: x = -19.2, y_test = -37.17087, closest_ideal = y41, residual = 1.4007900000000006
# Test Data Index 204: x = -11.0, y_test = -20.263054, closest_ideal = y41, residual = 1.2369519999999987
# Test Data Index 205: x = 0.8, y_test = 1.4264555, closest_ideal = y41, residual = 0.5322224999999998
# Test Data Index 206: x = 14.0, y_test = -0.06650608, closest_ideal = y48, residual = 0.13423253
# Test Data Index 207: x = -10.4, y_test = -2.007094, closest_ideal = y48, residual = 1.7748952
# Test Data Index 208: x = -15.0, y_test = -0.20536347, closest_ideal = y48, residual = 0.45237137
# Test Data Index 209: x = 5.8, y_test = 10.711373, closest_ideal = y41, residual = 0.656326
# Test Data Index 210: x = -7.6, y_test = -39.4954, closest_ideal = y41, residual = 23.811439999999997
# Test Data Index 211: x = -19.8, y_test = -19.915014, closest_ideal = y11, residual = 0.11501399999999862
# Test Data Index 212: x = 18.9, y_test = 19.193245, closest_ideal = y11, residual = 0.2932450000000024
# Test Data Index 213: x = 6.9, y_test = 7.8014545, closest_ideal = y11, residual = 0.9014544999999998
# Test Data Index 214: x = 8.8, y_test = -0.7260513, closest_ideal = y48, residual = 0.48884017999999996
# Test Data Index 215: x = -9.5, y_test = -9.652251, closest_ideal = y11, residual = 0.1522509999999997
# Test Data Index 216: x = 8.1, y_test = -16.659458, closest_ideal = y42, residual = 0.3376860000000015
# Test Data Index 217: x = 7.7, y_test = -14.40003, closest_ideal = y42, residual = 0.9232830000000014
# Test Data Index 218: x = 4.5, y_test = -0.8401146, closest_ideal = y48, residual = 0.9431442200000001
# Test Data Index 219: x = 10.7, y_test = 38.790028, closest_ideal = y41, residual = 17.868346
# Test Data Index 220: x = -8.8, y_test = 16.571745, closest_ideal = y42, residual = 0.6227090000000004
# Test Data Index 221: x = 11.7, y_test = 31.159376, closest_ideal = y41, residual = 8.140367000000001
# Test Data Index 222: x = -15.4, y_test = 29.490164, closest_ideal = y42, residual = 0.833359999999999
# Test Data Index 223: x = 13.9, y_test = 15.310406, closest_ideal = y11, residual = 1.410406
# Test Data Index 224: x = -17.9, y_test = 1.1692159, closest_ideal = y48, residual = 0.9325691899999999
# Test Data Index 225: x = -3.1, y_test = -2.7701359, closest_ideal = y11, residual = 0.3298641
# Test Data Index 226: x = -10.1, y_test = -40.44977, closest_ideal = y41, residual = 20.562305000000002
# Test Data Index 227: x = -11.8, y_test = 24.606413, closest_ideal = y42, residual = 0.6461959999999998
# Test Data Index 228: x = 18.8, y_test = 37.5234, closest_ideal = y41, residual = 0.05183299999999491
# Test Data Index 229: x = -14.3, y_test = -30.492392, closest_ideal = y41, residual = 1.399006
# Test Data Index 230: x = 6.3, y_test = 13.4726305, closest_ideal = y41, residual = 0.8642234999999996
# Test Data Index 231: x = -18.8, y_test = 13.410461, closest_ideal = y48, residual = 13.385723586
# Test Data Index 232: x = 7.7, y_test = 15.392297, closest_ideal = y41, residual = 0.5017870000000002
# Test Data Index 233: x = -2.8, y_test = -3.2989988, closest_ideal = y11, residual = 0.4989988000000003
# Test Data Index 234: x = -8.2, y_test = -16.575344, closest_ideal = y41, residual = 0.2950209999999984
# Test Data Index 235: x = 2.8, y_test = -36.151726, closest_ideal = y42, residual = 30.080614999999995
# Test Data Index 236: x = 14.1, y_test = 0.31000805, closest_ideal = y48, residual = 0.29144169
# Test Data Index 237: x = -4.0, y_test = -8.339117, closest_ideal = y41, residual = 0.7175183
# Test Data Index 238: x = 5.8, y_test = 11.520408, closest_ideal = y41, residual = 0.15270899999999976
# Test Data Index 239: x = 17.1, y_test = -34.927006, closest_ideal = y42, residual = 0.6381000000000014
# Test Data Index 240: x = 13.5, y_test = -21.734203, closest_ideal = y42, residual = 4.968336999999998
# Test Data Index 241: x = 14.7, y_test = -0.27583703, closest_ideal = y48, residual = 0.05019836999999999
# Test Data Index 242: x = 13.7, y_test = 28.15797, closest_ideal = y41, residual = 0.3049919999999986
# Test Data Index 243: x = -7.9, y_test = -0.21800028, closest_ideal = y48, residual = 0.240976993
# Test Data Index 244: x = -7.3, y_test = -9.224243, closest_ideal = y11, residual = 1.9242429999999997
# Test Data Index 245: x = -9.1, y_test = -8.293134, closest_ideal = y11, residual = 0.8068659999999994
# Test Data Index 246: x = 4.6, y_test = -7.905099, closest_ideal = y42, residual = 1.3509770000000003
# Test Data Index 247: x = 19.7, y_test = 38.955273, closest_ideal = y41, residual = 0.8205140000000029
# Test Data Index 248: x = 17.6, y_test = -35.10534, closest_ideal = y42, residual = 0.06320999999999799
# Test Data Index 249: x = -4.5, y_test = -9.88685, closest_ideal = y41, residual = 1.3756150000000016
# Test Data Index 250: x = -5.7, y_test = 2.4492908, closest_ideal = y48, residual = 2.21945867
# Test Data Index 251: x = 13.6, y_test = 12.65079, closest_ideal = y11, residual = 0.949209999999999
# Test Data Index 252: x = -1.0, y_test = 38.057026, closest_ideal = y42, residual = 35.7868749
# Test Data Index 253: x = 3.0, y_test = -0.24295843, closest_ideal = y48, residual = 0.17310456000000002
# Test Data Index 254: x = -18.3, y_test = -19.014248, closest_ideal = y11, residual = 0.7142479999999978
# Test Data Index 255: x = 7.7, y_test = 7.778326, closest_ideal = y11, residual = 0.07832599999999967
# Test Data Index 256: x = -12.4, y_test = 1.2345738, closest_ideal = y48, residual = 1.15291502
# Test Data Index 257: x = 11.7, y_test = 11.846094, closest_ideal = y11, residual = 0.1460940000000015
# Test Data Index 258: x = -2.8, y_test = -2.6560864, closest_ideal = y11, residual = 0.14391359999999986
# Test Data Index 259: x = -9.7, y_test = 18.183699, closest_ideal = y42, residual = 0.735119000000001
# Test Data Index 260: x = 10.4, y_test = 10.410377, closest_ideal = y11, residual = 0.01037700000000008
# Test Data Index 261: x = -19.1, y_test = -38.155376, closest_ideal = y41, residual = 0.16854100000000471
# Test Data Index 262: x = -14.7, y_test = -23.71317, closest_ideal = y41, residual = 6.109703999999997
# Test Data Index 263: x = 9.2, y_test = 7.5970726, closest_ideal = y11, residual = 1.6029273999999996
# Test Data Index 264: x = -9.6, y_test = -10.995601, closest_ideal = y11, residual = 1.395601000000001
# Test Data Index 265: x = -3.2, y_test = 7.2523284, closest_ideal = y42, residual = 1.3514757
# Test Data Index 266: x = -10.6, y_test = 19.67348, closest_ideal = y42, residual = 1.3338520000000003
# Test Data Index 267: x = -12.5, y_test = 25.675346, closest_ideal = y42, residual = 0.1764460000000021
# Test Data Index 268: x = -5.3, y_test = -4.3722925, closest_ideal = y11, residual = 0.9277074999999995
# Test Data Index 269: x = 14.6, y_test = -0.677509, closest_ideal = y48, residual = 0.47775363000000004
# Test Data Index 270: x = -16.8, y_test = -34.480774, closest_ideal = y41, residual = 1.3245579999999961
# Test Data Index 271: x = 2.842171e-13, y_test = 1.0261426, closest_ideal = y42, residual = 0.5261426
# Test Data Index 272: x = 5.7, y_test = 31.600712, closest_ideal = y41, residual = 20.476054
# Test Data Index 273: x = -4.6, y_test = -0.4953994, closest_ideal = y48, residual = 0.43967691999999997
# Test Data Index 274: x = -15.0, y_test = -13.989205, closest_ideal = y11, residual = 1.0107949999999999
# Test Data Index 275: x = -1.3, y_test = 17.94832, closest_ideal = y42, residual = 15.214570599999998
# Test Data Index 276: x = -4.6, y_test = -3.321962, closest_ideal = y11, residual = 1.2780379999999996
# Test Data Index 277: x = -8.2, y_test = 15.767493, closest_ideal = y42, residual = 0.4629299999999983
# Test Data Index 278: x = 13.3, y_test = 27.148037, closest_ideal = y41, residual = 0.21325299999999814
# Test Data Index 279: x = 18.2, y_test = 18.535152, closest_ideal = y11, residual = 0.3351520000000008
# Test Data Index 280: x = -10.0, y_test = 18.979424, closest_ideal = y42, residual = 0.6010390000000001
# Test Data Index 281: x = -12.0, y_test = 0.670648, closest_ideal = y48, residual = 0.4442534
# Test Data Index 282: x = 18.7, y_test = 0.8322721, closest_ideal = y48, residual = 0.90594
# Test Data Index 283: x = -20.0, y_test = -19.28497, closest_ideal = y11, residual = 0.7150299999999987
# Test Data Index 284: x = 12.5, y_test = 23.7267, closest_ideal = y41, residual = 1.2401389999999992
# Test Data Index 285: x = -19.3, y_test = -38.458572, closest_ideal = y41, residual = 0.3591120000000032
# Test Data Index 286: x = 16.3, y_test = 16.863394, closest_ideal = y11, residual = 0.5633939999999988
# Test Data Index 287: x = 6.7, y_test = 6.232807, closest_ideal = y11, residual = 0.46719299999999997
# Test Data Index 288: x = 9.8, y_test = -21.007133, closest_ideal = y42, residual = 0.9419210000000007
# Test Data Index 289: x = 10.1, y_test = 20.669428, closest_ideal = y41, residual = 0.7819630000000011
# Test Data Index 290: x = 13.6, y_test = 28.536507, closest_ideal = y41, residual = 0.9069259999999986
# Test Data Index 291: x = -14.4, y_test = -15.698657, closest_ideal = y11, residual = 1.2986570000000004
# Test Data Index 292: x = -9.1, y_test = -31.648926, closest_ideal = y41, residual = 13.289376999999998
# Test Data Index 293: x = 16.6, y_test = -33.41535, closest_ideal = y42, residual = 0.09856200000000115
# Test Data Index 294: x = -12.4, y_test = 26.599438, closest_ideal = y42, residual = 1.3063409999999998
# Test Data Index 295: x = -1.9, y_test = -4.0369043, closest_ideal = y41, residual = 0.23624570000000045
# Test Data Index 296: x = 12.2, y_test = -0.010358215, closest_ideal = y48, residual = 0.156869245
# Test Data Index 297: x = 16.5, y_test = -33.964134, closest_ideal = y42, residual = 0.6129340000000028
# Test Data Index 298: x = 5.3, y_test = -10.291622, closest_ideal = y42, residual = 0.031190999999999747
# Test Data Index 299: x = 17.9, y_test = 28.078455, closest_ideal = y41, residual = 7.314964999999997
# Test Data Index 300: x = 17.5, y_test = 34.16104, closest_ideal = y41, residual = 0.351148000000002
# Test Data Index 301: x = 0.3, y_test = 1.2151024, closest_ideal = y41, residual = 0.4673422999999999
# Test Data Index 302: x = -8.7, y_test = -16.843908, closest_ideal = y41, residual = 0.8875770000000003
# Test Data Index 303: x = -19.2, y_test = -37.17087, closest_ideal = y41, residual = 1.4007900000000006
# Test Data Index 304: x = -11.0, y_test = -20.263054, closest_ideal = y41, residual = 1.2369519999999987
# Test Data Index 305: x = 0.8, y_test = 1.4264555, closest_ideal = y41, residual = 0.5322224999999998
# Test Data Index 306: x = 14.0, y_test = -0.06650608, closest_ideal = y48, residual = 0.13423253
# Test Data Index 307: x = -10.4, y_test = -2.007094, closest_ideal = y48, residual = 1.7748952
# Test Data Index 308: x = -15.0, y_test = -0.20536347, closest_ideal = y48, residual = 0.45237137
# Test Data Index 309: x = 5.8, y_test = 10.711373, closest_ideal = y41, residual = 0.656326
# Test Data Index 310: x = -7.6, y_test = -39.4954, closest_ideal = y41, residual = 23.811439999999997
# Test Data Index 311: x = -19.8, y_test = -19.915014, closest_ideal = y11, residual = 0.11501399999999862
# Test Data Index 312: x = 18.9, y_test = 19.193245, closest_ideal = y11, residual = 0.2932450000000024
# Test Data Index 313: x = 6.9, y_test = 7.8014545, closest_ideal = y11, residual = 0.9014544999999998
# Test Data Index 314: x = 8.8, y_test = -0.7260513, closest_ideal = y48, residual = 0.48884017999999996
# Test Data Index 315: x = -9.5, y_test = -9.652251, closest_ideal = y11, residual = 0.1522509999999997
# Test Data Index 316: x = 8.1, y_test = -16.659458, closest_ideal = y42, residual = 0.3376860000000015
# Test Data Index 317: x = 7.7, y_test = -14.40003, closest_ideal = y42, residual = 0.9232830000000014
# Test Data Index 318: x = 4.5, y_test = -0.8401146, closest_ideal = y48, residual = 0.9431442200000001
# Test Data Index 319: x = 10.7, y_test = 38.790028, closest_ideal = y41, residual = 17.868346
# Test Data Index 320: x = -8.8, y_test = 16.571745, closest_ideal = y42, residual = 0.6227090000000004
# Test Data Index 321: x = 11.7, y_test = 31.159376, closest_ideal = y41, residual = 8.140367000000001
# Test Data Index 322: x = -15.4, y_test = 29.490164, closest_ideal = y42, residual = 0.833359999999999
# Test Data Index 323: x = 13.9, y_test = 15.310406, closest_ideal = y11, residual = 1.410406
# Test Data Index 324: x = -17.9, y_test = 1.1692159, closest_ideal = y48, residual = 0.9325691899999999
# Test Data Index 325: x = -3.1, y_test = -2.7701359, closest_ideal = y11, residual = 0.3298641
# Test Data Index 326: x = -10.1, y_test = -40.44977, closest_ideal = y41, residual = 20.562305000000002
# Test Data Index 327: x = -11.8, y_test = 24.606413, closest_ideal = y42, residual = 0.6461959999999998
# Test Data Index 328: x = 18.8, y_test = 37.5234, closest_ideal = y41, residual = 0.05183299999999491
# Test Data Index 329: x = -14.3, y_test = -30.492392, closest_ideal = y41, residual = 1.399006
# Test Data Index 330: x = 6.3, y_test = 13.4726305, closest_ideal = y41, residual = 0.8642234999999996
# Test Data Index 331: x = -18.8, y_test = 13.410461, closest_ideal = y48, residual = 13.385723586
# Test Data Index 332: x = 7.7, y_test = 15.392297, closest_ideal = y41, residual = 0.5017870000000002
# Test Data Index 333: x = -2.8, y_test = -3.2989988, closest_ideal = y11, residual = 0.4989988000000003
# Test Data Index 334: x = -8.2, y_test = -16.575344, closest_ideal = y41, residual = 0.2950209999999984
# Test Data Index 335: x = 2.8, y_test = -36.151726, closest_ideal = y42, residual = 30.080614999999995
# Test Data Index 336: x = 14.1, y_test = 0.31000805, closest_ideal = y48, residual = 0.29144169
# Test Data Index 337: x = -4.0, y_test = -8.339117, closest_ideal = y41, residual = 0.7175183
# Test Data Index 338: x = 5.8, y_test = 11.520408, closest_ideal = y41, residual = 0.15270899999999976
# Test Data Index 339: x = 17.1, y_test = -34.927006, closest_ideal = y42, residual = 0.6381000000000014
# Test Data Index 340: x = 13.5, y_test = -21.734203, closest_ideal = y42, residual = 4.968336999999998
# Test Data Index 341: x = 14.7, y_test = -0.27583703, closest_ideal = y48, residual = 0.05019836999999999
# Test Data Index 342: x = 13.7, y_test = 28.15797, closest_ideal = y41, residual = 0.3049919999999986
# Test Data Index 343: x = -7.9, y_test = -0.21800028, closest_ideal = y48, residual = 0.240976993
# Test Data Index 344: x = -7.3, y_test = -9.224243, closest_ideal = y11, residual = 1.9242429999999997
# Test Data Index 345: x = -9.1, y_test = -8.293134, closest_ideal = y11, residual = 0.8068659999999994
# Test Data Index 346: x = 4.6, y_test = -7.905099, closest_ideal = y42, residual = 1.3509770000000003
# Test Data Index 347: x = 19.7, y_test = 38.955273, closest_ideal = y41, residual = 0.8205140000000029
# Test Data Index 348: x = 17.6, y_test = -35.10534, closest_ideal = y42, residual = 0.06320999999999799
# Test Data Index 349: x = -4.5, y_test = -9.88685, closest_ideal = y41, residual = 1.3756150000000016
# Test Data Index 350: x = -5.7, y_test = 2.4492908, closest_ideal = y48, residual = 2.21945867
# Test Data Index 351: x = 13.6, y_test = 12.65079, closest_ideal = y11, residual = 0.949209999999999
# Test Data Index 352: x = -1.0, y_test = 38.057026, closest_ideal = y42, residual = 35.7868749
# Test Data Index 353: x = 3.0, y_test = -0.24295843, closest_ideal = y48, residual = 0.17310456000000002
# Test Data Index 354: x = -18.3, y_test = -19.014248, closest_ideal = y11, residual = 0.7142479999999978
# Test Data Index 355: x = 7.7, y_test = 7.778326, closest_ideal = y11, residual = 0.07832599999999967
# Test Data Index 356: x = -12.4, y_test = 1.2345738, closest_ideal = y48, residual = 1.15291502
# Test Data Index 357: x = 11.7, y_test = 11.846094, closest_ideal = y11, residual = 0.1460940000000015
# Test Data Index 358: x = -2.8, y_test = -2.6560864, closest_ideal = y11, residual = 0.14391359999999986
# Test Data Index 359: x = -9.7, y_test = 18.183699, closest_ideal = y42, residual = 0.735119000000001
# Test Data Index 360: x = 10.4, y_test = 10.410377, closest_ideal = y11, residual = 0.01037700000000008
# Test Data Index 361: x = -19.1, y_test = -38.155376, closest_ideal = y41, residual = 0.16854100000000471
# Test Data Index 362: x = -14.7, y_test = -23.71317, closest_ideal = y41, residual = 6.109703999999997
# Test Data Index 363: x = 9.2, y_test = 7.5970726, closest_ideal = y11, residual = 1.6029273999999996
# Test Data Index 364: x = -9.6, y_test = -10.995601, closest_ideal = y11, residual = 1.395601000000001
# Test Data Index 365: x = -3.2, y_test = 7.2523284, closest_ideal = y42, residual = 1.3514757
# Test Data Index 366: x = -10.6, y_test = 19.67348, closest_ideal = y42, residual = 1.3338520000000003
# Test Data Index 367: x = -12.5, y_test = 25.675346, closest_ideal = y42, residual = 0.1764460000000021
# Test Data Index 368: x = -5.3, y_test = -4.3722925, closest_ideal = y11, residual = 0.9277074999999995
# Test Data Index 369: x = 14.6, y_test = -0.677509, closest_ideal = y48, residual = 0.47775363000000004
# Test Data Index 370: x = -16.8, y_test = -34.480774, closest_ideal = y41, residual = 1.3245579999999961
# Test Data Index 371: x = 2.842171e-13, y_test = 1.0261426, closest_ideal = y42, residual = 0.5261426
# Test Data Index 372: x = 5.7, y_test = 31.600712, closest_ideal = y41, residual = 20.476054
# Test Data Index 373: x = -4.6, y_test = -0.4953994, closest_ideal = y48, residual = 0.43967691999999997
# Test Data Index 374: x = -15.0, y_test = -13.989205, closest_ideal = y11, residual = 1.0107949999999999
# Test Data Index 375: x = -1.3, y_test = 17.94832, closest_ideal = y42, residual = 15.214570599999998
# Test Data Index 376: x = -4.6, y_test = -3.321962, closest_ideal = y11, residual = 1.2780379999999996
# Test Data Index 377: x = -8.2, y_test = 15.767493, closest_ideal = y42, residual = 0.4629299999999983
# Test Data Index 378: x = 13.3, y_test = 27.148037, closest_ideal = y41, residual = 0.21325299999999814
# Test Data Index 379: x = 18.2, y_test = 18.535152, closest_ideal = y11, residual = 0.3351520000000008
# Test Data Index 380: x = -10.0, y_test = 18.979424, closest_ideal = y42, residual = 0.6010390000000001
# Test Data Index 381: x = -12.0, y_test = 0.670648, closest_ideal = y48, residual = 0.4442534
# Test Data Index 382: x = 18.7, y_test = 0.8322721, closest_ideal = y48, residual = 0.90594
# Test Data Index 383: x = -20.0, y_test = -19.28497, closest_ideal = y11, residual = 0.7150299999999987
# Test Data Index 384: x = 12.5, y_test = 23.7267, closest_ideal = y41, residual = 1.2401389999999992
# Test Data Index 385: x = -19.3, y_test = -38.458572, closest_ideal = y41, residual = 0.3591120000000032
# Test Data Index 386: x = 16.3, y_test = 16.863394, closest_ideal = y11, residual = 0.5633939999999988
# Test Data Index 387: x = 6.7, y_test = 6.232807, closest_ideal = y11, residual = 0.46719299999999997
# Test Data Index 388: x = 9.8, y_test = -21.007133, closest_ideal = y42, residual = 0.9419210000000007
# Test Data Index 389: x = 10.1, y_test = 20.669428, closest_ideal = y41, residual = 0.7819630000000011
# Test Data Index 390: x = 13.6, y_test = 28.536507, closest_ideal = y41, residual = 0.9069259999999986
# Test Data Index 391: x = -14.4, y_test = -15.698657, closest_ideal = y11, residual = 1.2986570000000004
# Test Data Index 392: x = -9.1, y_test = -31.648926, closest_ideal = y41, residual = 13.289376999999998
# Test Data Index 393: x = 16.6, y_test = -33.41535, closest_ideal = y42, residual = 0.09856200000000115
# Test Data Index 394: x = -12.4, y_test = 26.599438, closest_ideal = y42, residual = 1.3063409999999998
# Test Data Index 395: x = -1.9, y_test = -4.0369043, closest_ideal = y41, residual = 0.23624570000000045
# Test Data Index 396: x = 12.2, y_test = -0.010358215, closest_ideal = y48, residual = 0.156869245
# Test Data Index 397: x = 16.5, y_test = -33.964134, closest_ideal = y42, residual = 0.6129340000000028
# Test Data Index 398: x = 5.3, y_test = -10.291622, closest_ideal = y42, residual = 0.031190999999999747
# Test Data Index 399: x = 17.9, y_test = 28.078455, closest_ideal = y41, residual = 7.314964999999997
# Test Data Index 400: x = 17.5, y_test = 34.16104, closest_ideal = y41, residual = 0.351148000000002
# Test Data Index 401: x = 0.3, y_test = 1.2151024, closest_ideal = y41, residual = 0.4673422999999999
# Test Data Index 402: x = -8.7, y_test = -16.843908, closest_ideal = y41, residual = 0.8875770000000003
# Test Data Index 403: x = -19.2, y_test = -37.17087, closest_ideal = y41, residual = 1.4007900000000006
# Test Data Index 404: x = -11.0, y_test = -20.263054, closest_ideal = y41, residual = 1.2369519999999987
# Test Data Index 405: x = 0.8, y_test = 1.4264555, closest_ideal = y41, residual = 0.5322224999999998
# Test Data Index 406: x = 14.0, y_test = -0.06650608, closest_ideal = y48, residual = 0.13423253
# Test Data Index 407: x = -10.4, y_test = -2.007094, closest_ideal = y48, residual = 1.7748952
# Test Data Index 408: x = -15.0, y_test = -0.20536347, closest_ideal = y48, residual = 0.45237137
# Test Data Index 409: x = 5.8, y_test = 10.711373, closest_ideal = y41, residual = 0.656326
# Test Data Index 410: x = -7.6, y_test = -39.4954, closest_ideal = y41, residual = 23.811439999999997
# Test Data Index 411: x = -19.8, y_test = -19.915014, closest_ideal = y11, residual = 0.11501399999999862
# Test Data Index 412: x = 18.9, y_test = 19.193245, closest_ideal = y11, residual = 0.2932450000000024
# Test Data Index 413: x = 6.9, y_test = 7.8014545, closest_ideal = y11, residual = 0.9014544999999998
# Test Data Index 414: x = 8.8, y_test = -0.7260513, closest_ideal = y48, residual = 0.48884017999999996
# Test Data Index 415: x = -9.5, y_test = -9.652251, closest_ideal = y11, residual = 0.1522509999999997
# Test Data Index 416: x = 8.1, y_test = -16.659458, closest_ideal = y42, residual = 0.3376860000000015
# Test Data Index 417: x = 7.7, y_test = -14.40003, closest_ideal = y42, residual = 0.9232830000000014
# Test Data Index 418: x = 4.5, y_test = -0.8401146, closest_ideal = y48, residual = 0.9431442200000001
# Test Data Index 419: x = 10.7, y_test = 38.790028, closest_ideal = y41, residual = 17.868346
# Test Data Index 420: x = -8.8, y_test = 16.571745, closest_ideal = y42, residual = 0.6227090000000004
# Test Data Index 421: x = 11.7, y_test = 31.159376, closest_ideal = y41, residual = 8.140367000000001
# Test Data Index 422: x = -15.4, y_test = 29.490164, closest_ideal = y42, residual = 0.833359999999999
# Test Data Index 423: x = 13.9, y_test = 15.310406, closest_ideal = y11, residual = 1.410406
# Test Data Index 424: x = -17.9, y_test = 1.1692159, closest_ideal = y48, residual = 0.9325691899999999
# Test Data Index 425: x = -3.1, y_test = -2.7701359, closest_ideal = y11, residual = 0.3298641
# Test Data Index 426: x = -10.1, y_test = -40.44977, closest_ideal = y41, residual = 20.562305000000002
# Test Data Index 427: x = -11.8, y_test = 24.606413, closest_ideal = y42, residual = 0.6461959999999998
# Test Data Index 428: x = 18.8, y_test = 37.5234, closest_ideal = y41, residual = 0.05183299999999491
# Test Data Index 429: x = -14.3, y_test = -30.492392, closest_ideal = y41, residual = 1.399006
# Test Data Index 430: x = 6.3, y_test = 13.4726305, closest_ideal = y41, residual = 0.8642234999999996
# Test Data Index 431: x = -18.8, y_test = 13.410461, closest_ideal = y48, residual = 13.385723586
# Test Data Index 432: x = 7.7, y_test = 15.392297, closest_ideal = y41, residual = 0.5017870000000002
# Test Data Index 433: x = -2.8, y_test = -3.2989988, closest_ideal = y11, residual = 0.4989988000000003
# Test Data Index 434: x = -8.2, y_test = -16.575344, closest_ideal = y41, residual = 0.2950209999999984
# Test Data Index 435: x = 2.8, y_test = -36.151726, closest_ideal = y42, residual = 30.080614999999995
# Test Data Index 436: x = 14.1, y_test = 0.31000805, closest_ideal = y48, residual = 0.29144169
# Test Data Index 437: x = -4.0, y_test = -8.339117, closest_ideal = y41, residual = 0.7175183
# Test Data Index 438: x = 5.8, y_test = 11.520408, closest_ideal = y41, residual = 0.15270899999999976
# Test Data Index 439: x = 17.1, y_test = -34.927006, closest_ideal = y42, residual = 0.6381000000000014
# Test Data Index 440: x = 13.5, y_test = -21.734203, closest_ideal = y42, residual = 4.968336999999998
# Test Data Index 441: x = 14.7, y_test = -0.27583703, closest_ideal = y48, residual = 0.05019836999999999
# Test Data Index 442: x = 13.7, y_test = 28.15797, closest_ideal = y41, residual = 0.3049919999999986
# Test Data Index 443: x = -7.9, y_test = -0.21800028, closest_ideal = y48, residual = 0.240976993
# Test Data Index 444: x = -7.3, y_test = -9.224243, closest_ideal = y11, residual = 1.9242429999999997
# Test Data Index 445: x = -9.1, y_test = -8.293134, closest_ideal = y11, residual = 0.8068659999999994
# Test Data Index 446: x = 4.6, y_test = -7.905099, closest_ideal = y42, residual = 1.3509770000000003
# Test Data Index 447: x = 19.7, y_test = 38.955273, closest_ideal = y41, residual = 0.8205140000000029
# Test Data Index 448: x = 17.6, y_test = -35.10534, closest_ideal = y42, residual = 0.06320999999999799
# Test Data Index 449: x = -4.5, y_test = -9.88685, closest_ideal = y41, residual = 1.3756150000000016
# Test Data Index 450: x = -5.7, y_test = 2.4492908, closest_ideal = y48, residual = 2.21945867
# Test Data Index 451: x = 13.6, y_test = 12.65079, closest_ideal = y11, residual = 0.949209999999999
# Test Data Index 452: x = -1.0, y_test = 38.057026, closest_ideal = y42, residual = 35.7868749
# Test Data Index 453: x = 3.0, y_test = -0.24295843, closest_ideal = y48, residual = 0.17310456000000002
# Test Data Index 454: x = -18.3, y_test = -19.014248, closest_ideal = y11, residual = 0.7142479999999978
# Test Data Index 455: x = 7.7, y_test = 7.778326, closest_ideal = y11, residual = 0.07832599999999967
# Test Data Index 456: x = -12.4, y_test = 1.2345738, closest_ideal = y48, residual = 1.15291502
# Test Data Index 457: x = 11.7, y_test = 11.846094, closest_ideal = y11, residual = 0.1460940000000015
# Test Data Index 458: x = -2.8, y_test = -2.6560864, closest_ideal = y11, residual = 0.14391359999999986
# Test Data Index 459: x = -9.7, y_test = 18.183699, closest_ideal = y42, residual = 0.735119000000001
# Test Data Index 460: x = 10.4, y_test = 10.410377, closest_ideal = y11, residual = 0.01037700000000008
# Test Data Index 461: x = -19.1, y_test = -38.155376, closest_ideal = y41, residual = 0.16854100000000471
# Test Data Index 462: x = -14.7, y_test = -23.71317, closest_ideal = y41, residual = 6.109703999999997
# Test Data Index 463: x = 9.2, y_test = 7.5970726, closest_ideal = y11, residual = 1.6029273999999996
# Test Data Index 464: x = -9.6, y_test = -10.995601, closest_ideal = y11, residual = 1.395601000000001
# Test Data Index 465: x = -3.2, y_test = 7.2523284, closest_ideal = y42, residual = 1.3514757
# Test Data Index 466: x = -10.6, y_test = 19.67348, closest_ideal = y42, residual = 1.3338520000000003
# Test Data Index 467: x = -12.5, y_test = 25.675346, closest_ideal = y42, residual = 0.1764460000000021
# Test Data Index 468: x = -5.3, y_test = -4.3722925, closest_ideal = y11, residual = 0.9277074999999995
# Test Data Index 469: x = 14.6, y_test = -0.677509, closest_ideal = y48, residual = 0.47775363000000004
# Test Data Index 470: x = -16.8, y_test = -34.480774, closest_ideal = y41, residual = 1.3245579999999961
# Test Data Index 471: x = 2.842171e-13, y_test = 1.0261426, closest_ideal = y42, residual = 0.5261426
# Test Data Index 472: x = 5.7, y_test = 31.600712, closest_ideal = y41, residual = 20.476054
# Test Data Index 473: x = -4.6, y_test = -0.4953994, closest_ideal = y48, residual = 0.43967691999999997
# Test Data Index 474: x = -15.0, y_test = -13.989205, closest_ideal = y11, residual = 1.0107949999999999
# Test Data Index 475: x = -1.3, y_test = 17.94832, closest_ideal = y42, residual = 15.214570599999998
# ...
# Test Data Index 1143: x = -7.9, y_test = -0.21800028, closest_ideal = y48, residual = 0.240976993
# Test Data Index 1144: x = -7.3, y_test = -9.224243, closest_ideal = y11, residual = 1.9242429999999997
# Test Data Index 1145: x = -9.1, y_test = -8.293134, closest_ideal = y11, residual = 0.8068659999999994
# Test Data Index 1146: x = 4.6, y_test = -7.905099, closest_ideal = y42, residual = 1.3509770000000003
# Test Data Index 1147: x = 19.7, y_test = 38.955273, closest_ideal = y41, residual = 0.8205140000000029
# Test Data Index 1148: x = 17.6, y_test = -35.10534, closest_ideal = y42, residual = 0.06320999999999799
# Test Data Index 1149: x = -4.5, y_test = -9.88685, closest_ideal = y41, residual = 1.3756150000000016
# Test Data Index 1150: x = -5.7, y_test = 2.4492908, closest_ideal = y48, residual = 2.21945867
# Test Data Index 1151: x = 13.6, y_test = 12.65079, closest_ideal = y11, residual = 0.949209999999999
# Test Data Index 1152: x = -1.0, y_test = 38.057026, closest_ideal = y42, residual = 35.7868749
# Test Data Index 1153: x = 3.0, y_test = -0.24295843, closest_ideal = y48, residual = 0.17310456000000002
# Test Data Index 1154: x = -18.3, y_test = -19.014248, closest_ideal = y11, residual = 0.7142479999999978
# Test Data Index 1155: x = 7.7, y_test = 7.778326, closest_ideal = y11, residual = 0.07832599999999967
# Test Data Index 1156: x = -12.4, y_test = 1.2345738, closest_ideal = y48, residual = 1.15291502
# Test Data Index 1157: x = 11.7, y_test = 11.846094, closest_ideal = y11, residual = 0.1460940000000015
# Test Data Index 1158: x = -2.8, y_test = -2.6560864, closest_ideal = y11, residual = 0.14391359999999986
# Test Data Index 1159: x = -9.7, y_test = 18.183699, closest_ideal = y42, residual = 0.735119000000001
# Test Data Index 1160: x = 10.4, y_test = 10.410377, closest_ideal = y11, residual = 0.01037700000000008
# Test Data Index 1161: x = -19.1, y_test = -38.155376, closest_ideal = y41, residual = 0.16854100000000471
# Test Data Index 1162: x = -14.7, y_test = -23.71317, closest_ideal = y41, residual = 6.109703999999997
# Test Data Index 1163: x = 9.2, y_test = 7.5970726, closest_ideal = y11, residual = 1.6029273999999996
# Test Data Index 1164: x = -9.6, y_test = -10.995601, closest_ideal = y11, residual = 1.395601000000001
# Test Data Index 1165: x = -3.2, y_test = 7.2523284, closest_ideal = y42, residual = 1.3514757
# Test Data Index 1166: x = -10.6, y_test = 19.67348, closest_ideal = y42, residual = 1.3338520000000003
# Test Data Index 1167: x = -12.5, y_test = 25.675346, closest_ideal = y42, residual = 0.1764460000000021
# Test Data Index 1168: x = -5.3, y_test = -4.3722925, closest_ideal = y11, residual = 0.9277074999999995
# Test Data Index 1169: x = 14.6, y_test = -0.677509, closest_ideal = y48, residual = 0.47775363000000004
# Test Data Index 1170: x = -16.8, y_test = -34.480774, closest_ideal = y41, residual = 1.3245579999999961
# Test Data Index 1171: x = 2.842171e-13, y_test = 1.0261426, closest_ideal = y42, residual = 0.5261426
# Test Data Index 1172: x = 5.7, y_test = 31.600712, closest_ideal = y41, residual = 20.476054
# Test Data Index 1173: x = -4.6, y_test = -0.4953994, closest_ideal = y48, residual = 0.43967691999999997
# Test Data Index 1174: x = -15.0, y_test = -13.989205, closest_ideal = y11, residual = 1.0107949999999999
# Test Data Index 1175: x = -1.3, y_test = 17.94832, closest_ideal = y42, residual = 15.214570599999998
# Test Data Index 1176: x = -4.6, y_test = -3.321962, closest_ideal = y11, residual = 1.2780379999999996
# Test Data Index 1177: x = -8.2, y_test = 15.767493, closest_ideal = y42, residual = 0.4629299999999983
# Test Data Index 1178: x = 13.3, y_test = 27.148037, closest_ideal = y41, residual = 0.21325299999999814
# Test Data Index 1179: x = 18.2, y_test = 18.535152, closest_ideal = y11, residual = 0.3351520000000008
# Test Data Index 1180: x = -10.0, y_test = 18.979424, closest_ideal = y42, residual = 0.6010390000000001
# Test Data Index 1181: x = -12.0, y_test = 0.670648, closest_ideal = y48, residual = 0.4442534
# Test Data Index 1182: x = 18.7, y_test = 0.8322721, closest_ideal = y48, residual = 0.90594
# Test Data Index 1183: x = -20.0, y_test = -19.28497, closest_ideal = y11, residual = 0.7150299999999987
# Test Data Index 1184: x = 12.5, y_test = 23.7267, closest_ideal = y41, residual = 1.2401389999999992
# Test Data Index 1185: x = -19.3, y_test = -38.458572, closest_ideal = y41, residual = 0.3591120000000032
# Test Data Index 1186: x = 16.3, y_test = 16.863394, closest_ideal = y11, residual = 0.5633939999999988
# Test Data Index 1187: x = 6.7, y_test = 6.232807, closest_ideal = y11, residual = 0.46719299999999997
# Test Data Index 1188: x = 9.8, y_test = -21.007133, closest_ideal = y42, residual = 0.9419210000000007
# Test Data Index 1189: x = 10.1, y_test = 20.669428, closest_ideal = y41, residual = 0.7819630000000011
# Test Data Index 1190: x = 13.6, y_test = 28.536507, closest_ideal = y41, residual = 0.9069259999999986
# Test Data Index 1191: x = -14.4, y_test = -15.698657, closest_ideal = y11, residual = 1.2986570000000004
# Test Data Index 1192: x = -9.1, y_test = -31.648926, closest_ideal = y41, residual = 13.289376999999998
# Test Data Index 1193: x = 16.6, y_test = -33.41535, closest_ideal = y42, residual = 0.09856200000000115
# Test Data Index 1194: x = -12.4, y_test = 26.599438, closest_ideal = y42, residual = 1.3063409999999998
# Test Data Index 1195: x = -1.9, y_test = -4.0369043, closest_ideal = y41, residual = 0.23624570000000045
# Test Data Index 1196: x = 12.2, y_test = -0.010358215, closest_ideal = y48, residual = 0.156869245
# Test Data Index 1197: x = 16.5, y_test = -33.964134, closest_ideal = y42, residual = 0.6129340000000028
# Test Data Index 1198: x = 5.3, y_test = -10.291622, closest_ideal = y42, residual = 0.031190999999999747
# Test Data Index 1199: x = 17.9, y_test = 28.078455, closest_ideal = y41, residual = 7.314964999999997
# Test Data Index 1200: x = 17.5, y_test = 34.16104, closest_ideal = y41, residual = 0.351148000000002
# Test Data Index 1201: x = 0.3, y_test = 1.2151024, closest_ideal = y41, residual = 0.4673422999999999
# Test Data Index 1202: x = -8.7, y_test = -16.843908, closest_ideal = y41, residual = 0.8875770000000003
# Test Data Index 1203: x = -19.2, y_test = -37.17087, closest_ideal = y41, residual = 1.4007900000000006
# Test Data Index 1204: x = -11.0, y_test = -20.263054, closest_ideal = y41, residual = 1.2369519999999987
# Test Data Index 1205: x = 0.8, y_test = 1.4264555, closest_ideal = y41, residual = 0.5322224999999998
# Test Data Index 1206: x = 14.0, y_test = -0.06650608, closest_ideal = y48, residual = 0.13423253
# Test Data Index 1207: x = -10.4, y_test = -2.007094, closest_ideal = y48, residual = 1.7748952
# Test Data Index 1208: x = -15.0, y_test = -0.20536347, closest_ideal = y48, residual = 0.45237137
# Test Data Index 1209: x = 5.8, y_test = 10.711373, closest_ideal = y41, residual = 0.656326
# Test Data Index 1210: x = -7.6, y_test = -39.4954, closest_ideal = y41, residual = 23.811439999999997
# Test Data Index 1211: x = -19.8, y_test = -19.915014, closest_ideal = y11, residual = 0.11501399999999862
# Test Data Index 1212: x = 18.9, y_test = 19.193245, closest_ideal = y11, residual = 0.2932450000000024
# Test Data Index 1213: x = 6.9, y_test = 7.8014545, closest_ideal = y11, residual = 0.9014544999999998
# Test Data Index 1214: x = 8.8, y_test = -0.7260513, closest_ideal = y48, residual = 0.48884017999999996
# Test Data Index 1215: x = -9.5, y_test = -9.652251, closest_ideal = y11, residual = 0.1522509999999997
# Test Data Index 1216: x = 8.1, y_test = -16.659458, closest_ideal = y42, residual = 0.3376860000000015
# Test Data Index 1217: x = 7.7, y_test = -14.40003, closest_ideal = y42, residual = 0.9232830000000014
# Test Data Index 1218: x = 4.5, y_test = -0.8401146, closest_ideal = y48, residual = 0.9431442200000001
# Test Data Index 1219: x = 10.7, y_test = 38.790028, closest_ideal = y41, residual = 17.868346
# Test Data Index 1220: x = -8.8, y_test = 16.571745, closest_ideal = y42, residual = 0.6227090000000004
# Test Data Index 1221: x = 11.7, y_test = 31.159376, closest_ideal = y41, residual = 8.140367000000001
# Test Data Index 1222: x = -15.4, y_test = 29.490164, closest_ideal = y42, residual = 0.833359999999999
# Test Data Index 1223: x = 13.9, y_test = 15.310406, closest_ideal = y11, residual = 1.410406
# Test Data Index 1224: x = -17.9, y_test = 1.1692159, closest_ideal = y48, residual = 0.9325691899999999
# Test Data Index 1225: x = -3.1, y_test = -2.7701359, closest_ideal = y11, residual = 0.3298641
# Test Data Index 1226: x = -10.1, y_test = -40.44977, closest_ideal = y41, residual = 20.562305000000002
# Test Data Index 1227: x = -11.8, y_test = 24.606413, closest_ideal = y42, residual = 0.6461959999999998
# Test Data Index 1228: x = 18.8, y_test = 37.5234, closest_ideal = y41, residual = 0.05183299999999491
# Test Data Index 1229: x = -14.3, y_test = -30.492392, closest_ideal = y41, residual = 1.399006
# Test Data Index 1230: x = 6.3, y_test = 13.4726305, closest_ideal = y41, residual = 0.8642234999999996
# Test Data Index 1231: x = -18.8, y_test = 13.410461, closest_ideal = y48, residual = 13.385723586
# Test Data Index 1232: x = 7.7, y_test = 15.392297, closest_ideal = y41, residual = 0.5017870000000002
# Test Data Index 1233: x = -2.8, y_test = -3.2989988, closest_ideal = y11, residual = 0.4989988000000003
# Test Data Index 1234: x = -8.2, y_test = -16.575344, closest_ideal = y41, residual = 0.2950209999999984
# Test Data Index 1235: x = 2.8, y_test = -36.151726, closest_ideal = y42, residual = 30.080614999999995
# Test Data Index 1236: x = 14.1, y_test = 0.31000805, closest_ideal = y48, residual = 0.29144169
# Test Data Index 1237: x = -4.0, y_test = -8.339117, closest_ideal = y41, residual = 0.7175183
# Test Data Index 1238: x = 5.8, y_test = 11.520408, closest_ideal = y41, residual = 0.15270899999999976
# Test Data Index 1239: x = 17.1, y_test = -34.927006, closest_ideal = y42, residual = 0.6381000000000014
# Test Data Index 1240: x = 13.5, y_test = -21.734203, closest_ideal = y42, residual = 4.968336999999998
# Test Data Index 1241: x = 14.7, y_test = -0.27583703, closest_ideal = y48, residual = 0.05019836999999999
# Test Data Index 1242: x = 13.7, y_test = 28.15797, closest_ideal = y41, residual = 0.3049919999999986
# Test Data Index 1243: x = -7.9, y_test = -0.21800028, closest_ideal = y48, residual = 0.240976993
# Test Data Index 1244: x = -7.3, y_test = -9.224243, closest_ideal = y11, residual = 1.9242429999999997
# Test Data Index 1245: x = -9.1, y_test = -8.293134, closest_ideal = y11, residual = 0.8068659999999994
# Test Data Index 1246: x = 4.6, y_test = -7.905099, closest_ideal = y42, residual = 1.3509770000000003
# Test Data Index 1247: x = 19.7, y_test = 38.955273, closest_ideal = y41, residual = 0.8205140000000029
# Test Data Index 1248: x = 17.6, y_test = -35.10534, closest_ideal = y42, residual = 0.06320999999999799
# Test Data Index 1249: x = -4.5, y_test = -9.88685, closest_ideal = y41, residual = 1.3756150000000016
# Test Data Index 1250: x = -5.7, y_test = 2.4492908, closest_ideal = y48, residual = 2.21945867
# Test Data Index 1251: x = 13.6, y_test = 12.65079, closest_ideal = y11, residual = 0.949209999999999
# Test Data Index 1252: x = -1.0, y_test = 38.057026, closest_ideal = y42, residual = 35.7868749
# Test Data Index 1253: x = 3.0, y_test = -0.24295843, closest_ideal = y48, residual = 0.17310456000000002
# Test Data Index 1254: x = -18.3, y_test = -19.014248, closest_ideal = y11, residual = 0.7142479999999978
# Test Data Index 1255: x = 7.7, y_test = 7.778326, closest_ideal = y11, residual = 0.07832599999999967
# Test Data Index 1256: x = -12.4, y_test = 1.2345738, closest_ideal = y48, residual = 1.15291502
# Test Data Index 1257: x = 11.7, y_test = 11.846094, closest_ideal = y11, residual = 0.1460940000000015
# Test Data Index 1258: x = -2.8, y_test = -2.6560864, closest_ideal = y11, residual = 0.14391359999999986
# Test Data Index 1259: x = -9.7, y_test = 18.183699, closest_ideal = y42, residual = 0.735119000000001
# Test Data Index 1260: x = 10.4, y_test = 10.410377, closest_ideal = y11, residual = 0.01037700000000008
# Test Data Index 1261: x = -19.1, y_test = -38.155376, closest_ideal = y41, residual = 0.16854100000000471
# Test Data Index 1262: x = -14.7, y_test = -23.71317, closest_ideal = y41, residual = 6.109703999999997
# Test Data Index 1263: x = 9.2, y_test = 7.5970726, closest_ideal = y11, residual = 1.6029273999999996
# Test Data Index 1264: x = -9.6, y_test = -10.995601, closest_ideal = y11, residual = 1.395601000000001
# Test Data Index 1265: x = -3.2, y_test = 7.2523284, closest_ideal = y42, residual = 1.3514757
# Test Data Index 1266: x = -10.6, y_test = 19.67348, closest_ideal = y42, residual = 1.3338520000000003
# Test Data Index 1267: x = -12.5, y_test = 25.675346, closest_ideal = y42, residual = 0.1764460000000021
# Test Data Index 1268: x = -5.3, y_test = -4.3722925, closest_ideal = y11, residual = 0.9277074999999995
# Test Data Index 1269: x = 14.6, y_test = -0.677509, closest_ideal = y48, residual = 0.47775363000000004
# Test Data Index 1270: x = -16.8, y_test = -34.480774, closest_ideal = y41, residual = 1.3245579999999961
# Test Data Index 1271: x = 2.842171e-13, y_test = 1.0261426, closest_ideal = y42, residual = 0.5261426
# Test Data Index 1272: x = 5.7, y_test = 31.600712, closest_ideal = y41, residual = 20.476054
# Test Data Index 1273: x = -4.6, y_test = -0.4953994, closest_ideal = y48, residual = 0.43967691999999997
# Test Data Index 1274: x = -15.0, y_test = -13.989205, closest_ideal = y11, residual = 1.0107949999999999
# Test Data Index 1275: x = -1.3, y_test = 17.94832, closest_ideal = y42, residual = 15.214570599999998
# Test Data Index 1276: x = -4.6, y_test = -3.321962, closest_ideal = y11, residual = 1.2780379999999996
# Test Data Index 1277: x = -8.2, y_test = 15.767493, closest_ideal = y42, residual = 0.4629299999999983
# Test Data Index 1278: x = 13.3, y_test = 27.148037, closest_ideal = y41, residual = 0.21325299999999814
# Test Data Index 1279: x = 18.2, y_test = 18.535152, closest_ideal = y11, residual = 0.3351520000000008
# Test Data Index 1280: x = -10.0, y_test = 18.979424, closest_ideal = y42, residual = 0.6010390000000001
# Test Data Index 1281: x = -12.0, y_test = 0.670648, closest_ideal = y48, residual = 0.4442534
# Test Data Index 1282: x = 18.7, y_test = 0.8322721, closest_ideal = y48, residual = 0.90594
# Test Data Index 1283: x = -20.0, y_test = -19.28497, closest_ideal = y11, residual = 0.7150299999999987
# Test Data Index 1284: x = 12.5, y_test = 23.7267, closest_ideal = y41, residual = 1.2401389999999992
# Test Data Index 1285: x = -19.3, y_test = -38.458572, closest_ideal = y41, residual = 0.3591120000000032
# Test Data Index 1286: x = 16.3, y_test = 16.863394, closest_ideal = y11, residual = 0.5633939999999988
# Test Data Index 1287: x = 6.7, y_test = 6.232807, closest_ideal = y11, residual = 0.46719299999999997
# Test Data Index 1288: x = 9.8, y_test = -21.007133, closest_ideal = y42, residual = 0.9419210000000007
# Test Data Index 1289: x = 10.1, y_test = 20.669428, closest_ideal = y41, residual = 0.7819630000000011
# Test Data Index 1290: x = 13.6, y_test = 28.536507, closest_ideal = y41, residual = 0.9069259999999986
# Test Data Index 1291: x = -14.4, y_test = -15.698657, closest_ideal = y11, residual = 1.2986570000000004
# Test Data Index 1292: x = -9.1, y_test = -31.648926, closest_ideal = y41, residual = 13.289376999999998
# Test Data Index 1293: x = 16.6, y_test = -33.41535, closest_ideal = y42, residual = 0.09856200000000115
# Test Data Index 1294: x = -12.4, y_test = 26.599438, closest_ideal = y42, residual = 1.3063409999999998
# Test Data Index 1295: x = -1.9, y_test = -4.0369043, closest_ideal = y41, residual = 0.23624570000000045
# Test Data Index 1296: x = 12.2, y_test = -0.010358215, closest_ideal = y48, residual = 0.156869245
# Test Data Index 1297: x = 16.5, y_test = -33.964134, closest_ideal = y42, residual = 0.6129340000000028
# Test Data Index 1298: x = 5.3, y_test = -10.291622, closest_ideal = y42, residual = 0.031190999999999747
# Test Data Index 1299: x = 17.9, y_test = 28.078455, closest_ideal = y41, residual = 7.314964999999997
